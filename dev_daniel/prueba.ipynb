# %%
import pandas as pd

# %%
df = pd.read_csv("moron.csv",encoding="utf-8",delimiter=",")

# %%
df
# Out:
#       Universidad de morón                              Licenciatura en artes  \
# 0     Universidad de morón                                          Agronomía
# 1     Universidad de morón                    Licenciatura en administración
# 2     Universidad de morón  Licenciatura en ciencia y tecnología de alimentos
# 3     Universidad de morón                Licenciatura en terapia ocupacional
# 4     Universidad de morón                              Ciencias veterinarias
# ...                    ...                                                ...
# 1854  Universidad de morón                              Ciencias veterinarias
# 1855  Universidad de morón                                          Actuario
# 1856  Universidad de morón         Licenciatura en ciencias de la computación
# 1857  Universidad de morón                    Licenciatura en administración
# 1858  Universidad de morón                          Ingeniería en informática
#
# ...
