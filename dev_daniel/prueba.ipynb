# %%
import pandas as pd

# %%
df = pd.read_csv('data/Universidad de morón.csv', encoding= 'utf-8')

# %%
df
# Out:
#                 university                                      career  \
# 0     Universidad de morón                       Licenciatura en artes
# 1               university                                      career
# 2     Universidad de morón                                   Agronomía
# 3               university                                      career
# 4     Universidad de morón             Licenciatura en administración
# ...                    ...                                         ...
# 3714  Universidad de morón  Licenciatura en ciencias de la computación
# 3715            university                                      career
# 3716  Universidad de morón             Licenciatura en administración
# 3717            university                                      career
# 3718  Universidad de morón                   Ingeniería en informática
#
#       inscription_date      first_name  gender         age  postal_code  \
# ...

# %%
df = pd.read_csv('data/Universidad-nacional-de-río-cuarto.csv', encoding= 'utf-8')

# %%
df
# Out:
#                               university                               career  \
# 0     Universidad-nacional-de-río-cuarto        Licenciatura-en-musicoterapia
# 1                             university                               career
# 2     Universidad-nacional-de-río-cuarto                             Farmacia
# 3                             university                               career
# 4     Universidad-nacional-de-río-cuarto                  Ingeniería-mecánica
# ...                                  ...                                  ...
# 3670  Universidad-nacional-de-río-cuarto    Licenciatura-en-ciencia-política-
# 3671                          university                               career
# 3672  Universidad-nacional-de-río-cuarto  Licenciatura-en-ciencias-biológicas
# 3673                          university                               career
# 3674  Universidad-nacional-de-río-cuarto                             Farmacia
#
# ...
